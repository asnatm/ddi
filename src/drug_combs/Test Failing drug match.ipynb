# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import json
from tqdm import tqdm, tqdm_notebook
from Identifiers_converter import Identifiers_converter
# %matplotlib inline

# %%
cache = {}
with open('cache.json') as f:
    cache = json.load(f)
cache_df = pd.DataFrame(zip(cache.keys(), cache.values()), columns=['drugName', 'drugID'])
cache_df
# Out:
#                                    drugName   drugID
# 0                               Ganciclovir  DB01004
# 1                                 Foscarnet  DB00529
# 2                                 Clozapine  DB00363
# 3                                   Glycine  DB00145
# 4                             D-cycloserine  DB00260
# ...                                     ...      ...
# 30513                      Heparin Infusion     None
# 30514                            Heparin SC     None
# 30515  Enoxaparin/Lovenox Intermediate Dose     None
# 30516                   Tirofiban Injection     None
# 30517                              Agrastat  DB00775
#
# [30518 rows x 2 columns]

# %%
def regex_or_x(x, regexes):
    for regex in regexes:
        res = regex.findall(x)
        if res != []:
            x = res[0]
    return x

# %%
comparator_regex = re.compile('Comparator: (.*)')
remove_mg_kg = re.compile('^(.*?)(?:(?:\/\d)|(?: \d)|(?:,(?:.*)\d)).*?(?:mg|kg|μg)(?:.*?)$')

regs = [comparator_regex, remove_mg_kg]
cache_df['cleanedDrugName'] = cache_df['drugName'].apply(lambda x: regex_or_x(x, regs))
# cache_df['cleanedDrugName'] = cache_df['cleanedDrugName'].apply(lambda x: x.split("/"))

# %%
cache_df[cache_df['drugName'] == 'Tositumomab 450 mg']
# Out:
#                 drugName drugID cleanedDrugName
# 2003  Tositumomab 450 mg   None     Tositumomab

# %%
print("Some examples for fixes:")
print(f'(Tositumomab 450 mg) --> ({regex_or_x("Tositumomab 450 mg", regs)})')
print(f'(Valsartan 160 mg capsules) --> ({regex_or_x("Valsartan 160 mg capsules", regs)})')
print(f'(Comparator: timolol maleate) --> ({regex_or_x("Comparator: timolol maleate", regs)})')
print(f'(Prochlorperazine 0.5 mg IV over 5 sec) --> ({regex_or_x("Prochlorperazine 0.5 mg IV over 5 sec", regs)})')
# Out:
# Some examples for fixes:
# (Tositumomab 450 mg) --> (Tositumomab)
# (Valsartan 160 mg capsules) --> (Valsartan)
# (Comparator: timolol maleate) --> (timolol maleate)
# (Prochlorperazine 0.5 mg IV over 5 sec) --> (Prochlorperazine)

# %%
print(f"Here we fixed {int(((cache_df['drugName'] != cache_df['cleanedDrugName']).sum() / cache_df['cleanedDrugName'].count()) *1000) / 1000} of the drug names")
# Out:
# Here we fixed 0.097 of the drug names

# %%
cache_df['changed'] = cache_df['drugName'] != cache_df['cleanedDrugName']
fixed_drugs_df = cache_df[cache_df['changed']]
for row in fixed_drugs_df.iterrows():
    row = row[1]
    print(f"({row[0]}) --> ({row[2]})")
# Out:
# (BCNU 200mg/m2) --> (BCNU)
# (BCNU 150mg/m2) --> (BCNU)
# (BCNU 80mg/m2) --> (BCNU)
# (TMZ 150mg/m2 six 6-week cycles) --> (TMZ)
# (TMZ 150mg/m2 six 8-week cycles) --> (TMZ)
# (temozolomide 150 mg/m^2) --> (temozolomide)
# (temozolomide 100 mg/m^2) --> (temozolomide)
# (temozolomide 200 mg/m^2) --> (temozolomide)
# (Bevacizumab 7.5 mg/kg) --> (Bevacizumab)
# (Oxaliplatin 130 mg/m^2) --> (Oxaliplatin)
# (Leucovorin 200 mg/m^2) --> (Leucovorin)
# (Capecitabine 1000 mg/m^2) --> (Capecitabine)
# (Bevacizumab 5 mg/kg) --> (Bevacizumab)
# (Fluorouracil 400 mg/m^2) --> (Fluorouracil)
# (Oxaliplatin 85 mg/m^2) --> (Oxaliplatin)
# (Palifermin 2 x 180 μg/kg/day) --> (Palifermin)
# (Palifermin 6 x 60 μg/kg/day) --> (Palifermin)
# (teduglutide 0.2 mg) --> (teduglutide)
# (Bosentan 125 mg) --> (Bosentan)
# (Bosentan 62.5 mg) --> (Bosentan)
# (Capecitabine 1650 mg/m^2/day) --> (Capecitabine)
# (Capecitabine 1200 mg/m^2/day) --> (Capecitabine)
# (Comparator: Pioglitazone) --> (Pioglitazone)
# (Comparator: Sitagliptin) --> (Sitagliptin)
# (dutasteride 0.5mg once daily for 4 years) --> (dutasteride)
# (tamsulosin 0.4mg once daily for 4 years) --> (tamsulosin)
# (Comparator: MK0518 combination therapy) --> (MK0518 combination therapy)
# (Comparator: tenofovir) --> (tenofovir)
# (Comparator: lamivudine) --> (lamivudine)
# (Comparator: efavirenz) --> (efavirenz)
# (Comparator: Metformin 1000 mg b.i.d.) --> (Metformin)
# (Comparator: Metformin 500 mg b.i.d.) --> (Metformin)
# (Comparator: MK0431 50 mg b.i.d. (b.i.d. = twice daily)) --> (MK0431)
# (Nicotine gum - 2 mg and 4 mg) --> (Nicotine gum -)
# (Nicotine lozenges - 2 mg and 4 mg) --> (Nicotine lozenges -)
# (TMC278 150 mg) --> (TMC278)
# (TMC278 75 mg) --> (TMC278)
# (TMC278 25 mg) --> (TMC278)
# (Ezetimibe 10mg) --> (Ezetimibe)
# (Simvastatin 20 mg) --> (Simvastatin)
# (Comparator: bexarotene) --> (bexarotene)
# (MK-0873 2.5 mg) --> (MK-0873)
# (Levetiracetam 500 mg) --> (Levetiracetam)
# (Levetiracetam 250 mg) --> (Levetiracetam)
# (Levetiracetam 166 mg) --> (Levetiracetam)
# (CDP791 10mg/kg) --> (CDP791)
# (CDP791 20mg/kg) --> (CDP791)
# (Micronized progesterone, 200 mg/day x 12 d/month) --> (Micronized progesterone)
# (Conjugated equine estrogens 0.45 mg/day) --> (Conjugated equine estrogens)
# (oxycodone 30 mg) --> (oxycodone)
# (oxycodone 15 mg) --> (oxycodone)
# (Benazepril/amlodipine 40/5 mg - Dose Level 2 from Month 1 to Month 2) --> (Benazepril/amlodipine)
# (Benazepril/hydrochlorothiazide 40/12.5 mg - Dose Level 2 from Month 1 to Month 2) --> (Benazepril/hydrochlorothiazide)
# (Benazepril/amlodipine 20/5 mg - Dose Level 1 from Day 1 to Month 1) --> (Benazepril/amlodipine)
# (Benazepril/amlodipine 40/10 mg - Dose Level 3 from Month 2 to Month 3 and thereafter) --> (Benazepril/amlodipine)
# (Benazepril/hydrochlorothiazide 20/12.5 mg - Dose Level 1 from Day 1 to Month 1) --> (Benazepril/hydrochlorothiazide)
# (Benazepril/hydrochlorothiazide 40/25 mg - Dose Level 3 from Month 2 to Month 3 and thereafter) --> (Benazepril/hydrochlorothiazide)
# (Valsartan 320 mg) --> (Valsartan)
# (Amlodipine 10 mg) --> (Amlodipine)
# (atomoxetine 1.2-1.4 mg/kg/day) --> (atomoxetine)
# (atomoxetine 0.5 mg/kg/day) --> (atomoxetine)
# (atomoxetine 1.2 mg/kg/day) --> (atomoxetine)
# (Modafinil 200mg) --> (Modafinil)
# (D-Amphetamine 30mg) --> (D-Amphetamine)
# (Losartan 50/100 mg) --> (Losartan)
# (Aliskiren 150/300 mg) --> (Aliskiren)
# (Imatinib 400 mg + Peg-Interferon) --> (Imatinib)
# (Imatinib mesylate 400 mg) --> (Imatinib mesylate)
# (Imatinib mesylate 600 mg) --> (Imatinib mesylate)
# (Imatinib mesylate 400 mg + Cytarabine) --> (Imatinib mesylate)
# (CEP-701 20mg) --> (CEP-701)
# (CEP-701 40mg) --> (CEP-701)
# (CEP-701 80mg) --> (CEP-701)
# (CEP-701 60mg) --> (CEP-701)
# (IPX054 250 mg) --> (IPX054)
# (CD-LD ER 250 mg) --> (CD-LD ER)
# (IPX054 150 mg) --> (IPX054)
# (CD-LD ER 150 mg) --> (CD-LD ER)
# (IPX054 100 mg) --> (IPX054)
# (CD-LD ER 100 mg) --> (CD-LD ER)
# (IPX054 200 mg) --> (IPX054)
# (CD-LD ER 200 mg) --> (CD-LD ER)
# (IPX054 300 mg) --> (IPX054)
# (CD-LD ER 300 mg) --> (CD-LD ER)
# (Tositumomab 450 mg) --> (Tositumomab)
# (Tositumomab 35 mg) --> (Tositumomab)
# (Comparator: Salmeterol) --> (Salmeterol)
# (Comparator: Montelukast) --> (Montelukast)
# (Ropinirole IR 2 mg) --> (Ropinirole IR)
# (Ropinirole CR 3 mg) --> (Ropinirole CR)
# (Ropinirole CR 2 mg) --> (Ropinirole CR)
# (Ropinirole IR 1 mg) --> (Ropinirole IR)
# (Golimumab 50 mg) --> (Golimumab)
# (Golimumab 100 mg) --> (Golimumab)
# (adjuvant TMZ 200mg) --> (adjuvant TMZ)
# (temozolomide(TMZ) 75mg) --> (temozolomide(TMZ))
# (Ospemifene 30 mg) --> (Ospemifene)
# (Ospemifene 60 mg) --> (Ospemifene)
# (Amlodipine 5 mg) --> (Amlodipine)
# (Telmisartan 40 mg) --> (Telmisartan)
# (Telmisartan 80 mg) --> (Telmisartan)
# (Amlodipine 2.5 mg) --> (Amlodipine)
# (Telmisartan 20 mg) --> (Telmisartan)
# (peginterferon alfa-2a 180μg) --> (peginterferon alfa-2a)
# (peginterferon alfa-2a 90μg) --> (peginterferon alfa-2a)
# (candesartan 8 mg) --> (candesartan)
# (valsartan 160 mg) --> (valsartan)
# (atenolol 50 mg) --> (atenolol)
# (ramipril 10 mg) --> (ramipril)
# (Alesse (20 mg ethinyl estradiol + 0.1 mg levonorgestrel)) --> (Alesse (20 mg ethinyl estradiol +)
# (Atorvastatin 10 mg) --> (Atorvastatin)
# (Cyclophosphamide 50mg) --> (Cyclophosphamide)
# (Cyclophosphamide 150mg) --> (Cyclophosphamide)
# (Cyclophosphamide 100mg) --> (Cyclophosphamide)
# (Comparator: dexamethasone) --> (dexamethasone)
# (Comparator: fosaprepitant dimeglumine) --> (fosaprepitant dimeglumine)
# (Comparator: ondansetron) --> (ondansetron)
# (pazopanib (GW786034) 800 mg) --> (pazopanib (GW786034))
# (pazopanib (GW786034) 400 mg) --> (pazopanib (GW786034))
# (lapatinib (GW572016) 1000 mg) --> (lapatinib (GW572016))
# (lapatinib (GW572016) 1500 mg) --> (lapatinib (GW572016))
# (prasugrel 10 mg) --> (prasugrel)
# (prasugrel 60 mg) --> (prasugrel)
# (Brivaracetam 25 mg) --> (Brivaracetam)
# (Brivaracetam 50 mg) --> (Brivaracetam)
# (Azithromycin 500 mg) --> (Azithromycin)
# (Everolimus 10 mg) --> (Everolimus)
# (BRV 25 mg) --> (BRV)
# (BRV 50 mg) --> (BRV)
# (Comparator: Truvada) --> (Truvada)
# (Itopride 200 mg) --> (Itopride)
# (Itopride 100 mg) --> (Itopride)
# (Dasatinib 100 mg) --> (Dasatinib)
# (Comparator: sitagliptin phosphate (MK0431)) --> (sitagliptin phosphate (MK0431))
# (Comparator: pioglitazone) --> (pioglitazone)
# (RO5024048 3000mg) --> (RO5024048)
# (RO5024048 1500mg) --> (RO5024048)
# (zolpidem tartrate sublingual tablet 3.5mg) --> (zolpidem tartrate sublingual tablet)
# (zolpidem tartrate sublingual tablet 1.75mg) --> (zolpidem tartrate sublingual tablet)
# (Metformin 2000 mg (ttd)) --> (Metformin)
# (Avandamet 2 mg/500 mg (ttd)) --> (Avandamet)
# (Avandamet 6 mg/1500 mg (ttd)) --> (Avandamet)
# (Metformin 1500 mg (ttd)) --> (Metformin)
# (Metformin 500 mg (ttd)) --> (Metformin)
# (Metformin 1000 mg (ttd)) --> (Metformin)
# (Avandamet 4 mg/1000 mg (ttd)) --> (Avandamet)
# (Avandamet 8 mg/ 2000 mg (ttd)) --> (Avandamet)
# (Azacitidine 40mg/m2) --> (Azacitidine)
# (Azacitidine 30mg/m2) --> (Azacitidine)
# (ATI-2042 200 mg) --> (ATI-2042)
# (Pramipexole 0.125 mg tablet) --> (Pramipexole)
# (Pramipexole 0.5 mg tablet) --> (Pramipexole)
# (Nitrofurantoin 100mg twice daily x 5 days) --> (Nitrofurantoin)
# (Budesonide inhalation suspension (0.5 mg/2mL) 2mg, albuterol (5mg/mL) 7.5 or 10mg) --> (Budesonide inhalation suspension (0.5 mg)
# (ibuprofen 200mg, and placebo pills) --> (ibuprofen)
# (Ziprasidone 160 mg/d) --> (Ziprasidone)
# (Ziprasidone 80-160 mg/d) --> (Ziprasidone)
# (Indacaterol 150 μg) --> (Indacaterol)
# (Indacaterol 300 μg) --> (Indacaterol)
# (casopitant 100 mg) --> (casopitant)
# (Casopitant 50 mg) --> (Casopitant)
# (Zoledronic acid 5 mg solution) --> (Zoledronic acid)
# (Alendronate 70 mg tablets) --> (Alendronate)
# (Comparator: atorvastatin calcium) --> (atorvastatin calcium)
# (Ofatumumab 1000mg) --> (Ofatumumab)
# (Ofatumumab 500mg) --> (Ofatumumab)
# (Sugammadex 2 mg/kg) --> (Sugammadex)
# (Sugammadex 0.5 mg/kg) --> (Sugammadex)
# (Sugammadex 1 mg/kg) --> (Sugammadex)
# (Sugammadex 4 mg/kg) --> (Sugammadex)
# (Triatec 5 mg) --> (Triatec)
# (Triatec 10 mg) --> (Triatec)
# (Norvasc 10 mg) --> (Norvasc)
# (Micardis 80 mg) --> (Micardis)
# (Ezetimibe 10 mg) --> (Ezetimibe)
# (Bortezomib 1.3 mg/m2) --> (Bortezomib)
# (Bortezomib 1.6 mg/m2) --> (Bortezomib)
# (Bortezomib 1.8 mg/m2) --> (Bortezomib)
# (Candesartan/HCT 32/25 mg) --> (Candesartan/HCT)
# (Calcium Carbonate 400 mg orally twice daily) --> (Calcium Carbonate)
# (Valsartan 160 mg capsules) --> (Valsartan)
# (Amlodipine 5 mg capsules) --> (Amlodipine)
# (Navarixin 10 mg) --> (Navarixin)
# (Navarixin 1 mg) --> (Navarixin)
# (Telcagepant potassium 150 mg) --> (Telcagepant potassium)
# (Telcagepant potassium 300 mg) --> (Telcagepant potassium)
# (Zolmitriptan 5 mg) --> (Zolmitriptan)
# (Telcagepant 300 mg soft gel capsules) --> (Telcagepant)
# (Telcagepant 280 mg tablets) --> (Telcagepant)
# (Comparator: dorzolamide hydrochloride) --> (dorzolamide hydrochloride)
# (Comparator: timolol maleate) --> (timolol maleate)
# (Valsartan 160mg daily) --> (Valsartan)
# (Valsartan 80mg daily) --> (Valsartan)
# (Casopitant 150 mg) --> (Casopitant)
# (Ribavirin (Copegus®) 1600 mg/day) --> (Ribavirin (Copegus®))
# (Pioglitazone 45 mg PO QD) --> (Pioglitazone)
# (Fenofibrate 145mg PO QD) --> (Fenofibrate)
# (Comparator: carboplatin) --> (carboplatin)
# (Comparator: paclitaxel) --> (paclitaxel)
# (Diphenhydramine 25 mg) --> (Diphenhydramine)
# (Metoclopramide 20 mg) --> (Metoclopramide)
# (metoclopramide 10 mg) --> (metoclopramide)
# (Inhaled alprazolam 1 mg) --> (Inhaled alprazolam)
# (Inhaled alprazolam 2 mg) --> (Inhaled alprazolam)
# (Comparator: simvastatin) --> (simvastatin)
# (Simvastatin 80mg) --> (Simvastatin)
# (Simvastatin 20mg plus ezetimibe 10mg) --> (Simvastatin)
# (simvastatin 20mg) --> (simvastatin)
# (Omalizumab 75-375 mg) --> (Omalizumab)
# (Moxifloxacin 400mg) --> (Moxifloxacin)
# (IPX056 30 mg) --> (IPX056)
# (Baclofen ER 30 mg) --> (Baclofen ER)
# (IPX056 35 mg) --> (IPX056)
# (Baclofen ER 35 mg) --> (Baclofen ER)
# (IPX056 40 mg) --> (IPX056)
# (Baclofen ER 40 mg) --> (Baclofen ER)
# (Encapsulated Baclofen 20 mg) --> (Encapsulated Baclofen)
# (IPX056 10 mg) --> (IPX056)
# (Baclofen ER 10 mg) --> (Baclofen ER)
# (IPX056 20 mg) --> (IPX056)
# (Baclofen ER 20 mg) --> (Baclofen ER)
# (Anecortave Acetate Sterile suspension 15 mg) --> (Anecortave Acetate Sterile suspension)
# (Comparator: carvedilol (+) hydrochlorothiazide) --> (carvedilol (+) hydrochlorothiazide)
# (Comparator: losartan (+) hydrochlorothiazide (HCTZ)) --> (losartan (+) hydrochlorothiazide (HCTZ))
# (Comparator: carvedilol) --> (carvedilol)
# (SB- 773812 60 mg) --> (SB-)
# (SB- 773812 120 mg) --> (SB-)
# (Comparator: carbidopa) --> (carbidopa)
# (Comparator: levodopa) --> (levodopa)
# (ZD6474 (vandetanib) 100mg) --> (ZD6474 (vandetanib))
# (ZD6474 (vandetanib) 300mg) --> (ZD6474 (vandetanib))
# (Artesunate (day 1,2,3: 4 mg/kg)) --> (Artesunate (day)
# (Sulphadoxine-pyrimethamine (day 1: 500mg S&25mg P/20 kg)) --> (Sulphadoxine-pyrimethamine (day)
# (Primaquine-base (day 3: 0.75 mg/kg)) --> (Primaquine-base (day)
# (Comparator: sitagliptin phosphate) --> (sitagliptin phosphate)
# (2.7 mg prednisolone plus 360 mg dipyridamole) --> (2.7 mg prednisolone plus)
# (2.7 mg prednisolone plus 90 mg dipyridamole) --> (2.7 mg prednisolone plus)
# (darunavir 800 mg) --> (darunavir)
# (FTC 200 mg/TDF 300mg) --> (FTC)
# (Ritonavir 100 mg) --> (Ritonavir)
# (SB-497115-GR 25mg) --> (SB-497115-GR)
# (SB-497115-GR 50 mg) --> (SB-497115-GR)
# (SB-497115-GR 50mg) --> (SB-497115-GR)
# (SB-497115-GR 12.5mg) --> (SB-497115-GR)
# (Comparator: sitagliptin phosphate (sitagliptin)) --> (sitagliptin phosphate (sitagliptin))
# (Comparator: Metformin) --> (Metformin)
# (Comparator: Rosiglitazone) --> (Rosiglitazone)
# (Seretide Diskus (salmeterol/fluticasone) 50/500 μg) --> (Seretide Diskus (salmeterol/fluticasone))
# (Symbicort Turbuhaler (budesonide/formoterol) 320/9 μg) --> (Symbicort Turbuhaler (budesonide/formoterol))
# (Inhaled prochlorperazine 10 mg) --> (Inhaled prochlorperazine)
# (Inhaled prochlorperazine 5 mg) --> (Inhaled prochlorperazine)
# (Loratadine Syrup 1 mg/mL Rescue Treatment) --> (Loratadine Syrup)
# (Prednisone 5 mg Rescue Treatment) --> (Prednisone)
# (Loratadine 10 mg Rescue Treatment) --> (Loratadine)
# (prednisolone 2.7 mg plus dipyridamole 180 mg) --> (prednisolone)
# (tenofovir DF 300 mg QD) --> (tenofovir DF)
# (emtricitabine 200 mg QD) --> (emtricitabine)
# (Nevirapine 200 mg BID) --> (Nevirapine)
# (Atazanavir 300 mg) --> (Atazanavir)
# (Budesonide inhalation suspension 0.25mg) --> (Budesonide inhalation suspension)
# (Budesonide inhalation suspension 0.5mg) --> (Budesonide inhalation suspension)
# (Prednisone 5 mg) --> (Prednisone)
# (Sinemet 200mg/50mg) --> (Sinemet)
# (pioglitazone HCl 45 mg) --> (pioglitazone HCl)
# (Insulin Glargine 0.5 u/kg body wt SC) --> (Insulin Glargine)
# (Insulin Glargine 1.5 u/kg body wt SC) --> (Insulin Glargine)
# (Insulin Glargine 2.0 u/kg body wt SC) --> (Insulin Glargine)
# (Insulin Glargine 1.0 u/kg body wt SC) --> (Insulin Glargine)
# (AMG 386 3mg/kg) --> (AMG)
# (AMG 386 10mg/kg) --> (AMG)
# (Oral alprazolam 1 mg) --> (Oral alprazolam)
# (Oral alprazolam 2 mg) --> (Oral alprazolam)
# (Oral alprazolam 2 mg qualifying session) --> (Oral alprazolam)
# (Inhaled alprazolam 0.5 mg) --> (Inhaled alprazolam)
# (Prochlorperazine 0.5 mg IV over 5 sec) --> (Prochlorperazine)
# (Prochlorperazine 10 mg IV over 5 sec) --> (Prochlorperazine)
# (Inhaled prochlorperazine 0.625 mg) --> (Inhaled prochlorperazine)
# (Comparator: Hydrochlorothiazide) --> (Hydrochlorothiazide)
# (Comparator: Aprepitant) --> (Aprepitant)
# (donepezil 2.5 mg and duloxetine 30mg) --> (donepezil)
# (Comparator: MK0249) --> (MK0249)
# (Comparator: modafinil) --> (modafinil)
# (Salmeterol 50 μg) --> (Salmeterol)
# (iloprost therapy up to 2 ng/kg x min) --> (iloprost therapy up to)
# (EVT 302, 10 mg) --> (EVT)
# (amlodipine 5 mg + delapril 30 mg) --> (amlodipine)
# (manidipine 10 mg + delapril 30 mg) --> (manidipine)
# (amlodipine 10 mg) --> (amlodipine)
# (manidipine 20 mg) --> (manidipine)
# (Vismodegib 150 mg) --> (Vismodegib)
# (Dexamethasone 40 mg) --> (Dexamethasone)
# (Ruxolitinib 25 mg) --> (Ruxolitinib)
# (Comparator: lenalidomide) --> (lenalidomide)
# (Comparator: vorinostat) --> (vorinostat)
# (Acetaminophen 4000 mg/d) --> (Acetaminophen)
# (Ibuprofen 800 mg/d) --> (Ibuprofen)
# (50 μg ethinylestradiol + 2.5 mg lynestrenol) --> (50 μg ethinylestradiol +)
# (Comparator: cyclosporine) --> (cyclosporine)
# (Cocaine 20mg) --> (Cocaine)
# (Cocaine 10mg) --> (Cocaine)
# (Cocaine 40mg) --> (Cocaine)
# (SYN117 160 mg) --> (SYN117)
# (SYN117 80 mg) --> (SYN117)
# (Fingolimod 1.25 mg) --> (Fingolimod)
# (Fingolimod 0.5 mg) --> (Fingolimod)
# (Comparator: Simvastatin 20, 40 and 80 mg) --> (Simvastatin)
# (Comparator: Atorvastatin) --> (Atorvastatin)
# (Comparator: Rosuvastatin) --> (Rosuvastatin)
# (Enalapril 5mg) --> (Enalapril)
# (Enalapril 10mg) --> (Enalapril)
# (Vardenafil (Levitra, BAY 38-9456), 20 mg) --> (Vardenafil (Levitra)
# (Vardenafil (Levitra, BAY 38-9456), 10 mg) --> (Vardenafil (Levitra)
# (Salmeterol/fluticasone (50/500 μg)) --> (Salmeterol/fluticasone (50)
# (CK-1827452 25mg capsule) --> (CK-1827452)
# (CK-1827452 48 mg and 11 mg iv infusion) --> (CK-1827452)
# (CK-1827452 12.5mg capsule) --> (CK-1827452)
# (CK-1827452 24mg and 6 mg iv infusion) --> (CK-1827452)
# (Diphenhydramine 25mg) --> (Diphenhydramine)
# (Aripiprazole 5mg) --> (Aripiprazole)
# (Aripiprazole 2mg) --> (Aripiprazole)
# (Vorapaxar 1 mg) --> (Vorapaxar)
# (Aspirin 75-150 mg) --> (Aspirin)
# (Vorapaxar 2.5 mg) --> (Vorapaxar)
# (Metformin 1500 mg daily) --> (Metformin)
# (Nitroglycerin 30mg) --> (Nitroglycerin)
# (Lidocaine 40mg) --> (Lidocaine)
# (Lidocaine 20mg) --> (Lidocaine)
# (Atenolol 50 mg tablets) --> (Atenolol)
# (Atenolol 100 mg tablets) --> (Atenolol)
# (Amlodipine 10 mg capsules) --> (Amlodipine)
# (Valsartan 40 mg) --> (Valsartan)
# (Valsartan 80 mg) --> (Valsartan)
# (Comparator: glimepiride) --> (glimepiride)
# (Corifollitropin Alfa 150 μg) --> (Corifollitropin Alfa)
# (Comparator: Pegylated-Interferon (Peg-IFN)) --> (Pegylated-Interferon (Peg-IFN))
# (Comparator: Vaniprevir) --> (Vaniprevir)
# (Comparator: Ribavirin) --> (Ribavirin)
# (Cilengitide 2000 mg once weekly) --> (Cilengitide)
# (Cilengitide 2000 mg twice weekly) --> (Cilengitide)
# (Moxaverin 150mg) --> (Moxaverin)
# (SB-742457 15mg) --> (SB-742457)
# (SB-742457 35mg) --> (SB-742457)
# (donepezil 5-10mg) --> (donepezil)
# (BIBW 2992 MA2 40mg/day) --> (BIBW)
# (BIBW 2992 MA2 50mg/day) --> (BIBW)
# (BIBW 2992 MA2 20mg/day) --> (BIBW)
# (CNTO 136 25 mg) --> (CNTO)
# (CNTO 136 50 mg) --> (CNTO)
# (CNTO 136 100 mg) --> (CNTO)
# (Prednisolone 30 mg) --> (Prednisolone)
# (Sitagliptin 100 mg) --> (Sitagliptin)
# (Rituximab 375 mg/m^2) --> (Rituximab)
# (Doxorubicin 50 mg/m^2) --> (Doxorubicin)
# (Vincristine 1.4 mg/m^2) --> (Vincristine)
# (VELCADE 1.3 mg/m^2) --> (VELCADE)
# (Prednisone 100 mg/m^2) --> (Prednisone)
# (Cyclophosphamide 750 mg/m^2) --> (Cyclophosphamide)
# (Ixabepilone, 32 mg/m^2) --> (Ixabepilone)
# (Paclitaxel, 200 mg/m^2) --> (Paclitaxel)
# (Milk Protein Extract Immunotherapy goal of 4mg/day) --> (Milk Protein Extract Immunotherapy goal of)
# (Milk Powder Immunotherapy goal dose 2000 mg/day) --> (Milk Powder Immunotherapy goal dose)
# (Milk Protein Extract Immunotherapy goal of 7mg/day) --> (Milk Protein Extract Immunotherapy goal of)
# (Milk Powder Immunotherapy goal dose 1000mg/day) --> (Milk Powder Immunotherapy goal dose)
# (Carvedilol-immediate release (IR) 2.5 mg tablet) --> (Carvedilol-immediate release (IR))
# (SK&F-105517-D 40 mg capsule) --> (SK&F-105517-D)
# (Carvedilol-IR 10 mg tablet) --> (Carvedilol-IR)
# (SK&F-105517-D 10 mg capsule) --> (SK&F-105517-D)
# (SK&F-105517-D 20 mg capsule) --> (SK&F-105517-D)
# (Comparator: Raltegravir 400 mg b.i.d.) --> (Raltegravir)
# (Experimental: Raltegravir 800 mg q.d.) --> (Experimental: Raltegravir)
# (Formoterol fumarate 12 μg DPI (F12D)) --> (Formoterol fumarate)
# (Formoterol fumarate 12 μg pMDI (F12M)) --> (Formoterol fumarate)
# (ZD6474 (Vandetanib at the dose of 100 mg)) --> (ZD6474 (Vandetanib at the dose of)
# (ZD6474 (Vandetanib at the dose of 300 mg)) --> (ZD6474 (Vandetanib at the dose of)
# (A1: AMG 386 10 mg/kg + Liposomal doxorubicin) --> (A1: AMG)
# (B3: AMG 386 15mg/kg + Topotecan) --> (B3: AMG)
# (A3: AMG 386 15mg/kg + Liposomal doxorubicin) --> (A3: AMG)
# (B1: AMG 386 10 mg/kg + Topotecan) --> (B1: AMG)
# (BI 201335 NA 240 mg BID) --> (BI)
# (BI 201335 NA 240 mg QD) --> (BI)
# (BI 201335 NA 120mg QD / LI) --> (BI)
# (BI 201335 NA 240 mg QD / LI) --> (BI)
# (Donepezil 10 mg) --> (Donepezil)
# (Donepezil 5 - 10 mg) --> (Donepezil)
# (ocrelizumab 500mg) --> (ocrelizumab)
# (ocrelizumabu 50mg) --> (ocrelizumabu)
# (ocrelizumabu 200mg) --> (ocrelizumabu)
# (Quinine 648 mg) --> (Quinine)
# (Theophylline 300 mg) --> (Theophylline)
# (atorvastatin 20 mg) --> (atorvastatin)
# (atorvastatin 40 mg) --> (atorvastatin)
# (Desloratadine 5 mg) --> (Desloratadine)
# (Aspirin 325mg) --> (Aspirin)
# (Quinine Sulfate 324 mg Capsules) --> (Quinine Sulfate)
# (Rosiglitazone 4 mg Tablets) --> (Rosiglitazone)
# (Ciprofloxacin 500 mg) --> (Ciprofloxacin)
# (Quinine Sulfate Capsules 324 mg) --> (Quinine Sulfate Capsules)
# (desloratadine 5 mg) --> (desloratadine)
# (Amantadine 300 mg) --> (Amantadine)
# (Desloratadine 5 mg (Clarinex)) --> (Desloratadine)
# (Brinzolamide 10 mg/ml/Timolol 5 mg/ml eye drops suspension) --> (Brinzolamide)
# (Brimonidine 20 mg/ml/Timolol 5 mg/ml eye drops solution) --> (Brimonidine)
# (PF-02413873 500 mg QD) --> (PF-02413873)
# (PF-02413873 1500 mg QD) --> (PF-02413873)
# (PF-02413873 20 mg QD) --> (PF-02413873)
# (PF-02413873 100 mg QD) --> (PF-02413873)
# (Comparator: alendronate) --> (alendronate)
# (Comparator: HCTZ) --> (HCTZ)
# (Gaboxadol 10 mg) --> (Gaboxadol)
# (Escitalopram 20 mg) --> (Escitalopram)
# (Gaboxadol 5 mg) --> (Gaboxadol)
# (Rivaroxaban 2.5 mg) --> (Rivaroxaban)
# (Rivaroxaban 5 mg) --> (Rivaroxaban)
# (PF-04878691 6mg) --> (PF-04878691)
# (PF-04878691 9mg) --> (PF-04878691)
# (PF-04878691 3mg) --> (PF-04878691)
# (paroxetine 10mg tablet) --> (paroxetine)
# (paroxetine 20mg tablet) --> (paroxetine)
# (Oxybutynin 2.5 mg) --> (Oxybutynin)
# (Desloratadine 2.5 mg) --> (Desloratadine)
# (Comparator: Blinded Ridaforolimus) --> (Blinded Ridaforolimus)
# (Etoricoxib 120 mg) --> (Etoricoxib)
# (Etoricoxib 90 mg) --> (Etoricoxib)
# (Ibuprofen 600 mg) --> (Ibuprofen)
# (Comparator: A: Pregabalin) --> (A: Pregabalin)
# (Comparator: C: Diphenhydramine hydrochloride) --> (C: Diphenhydramine hydrochloride)
# (Comparator: B: Duloxetine) --> (B: Duloxetine)
# (TMC310911 75 mg twice daily) --> (TMC310911)
# (Ritonavir 100 mg twice daily) --> (Ritonavir)
# (TMC310911 300 mg once daily) --> (TMC310911)
# (TMC310911 150 mg twice daily) --> (TMC310911)
# (Ritonavir 100 mg once daily) --> (Ritonavir)
# (TMC310911 300 mg twice daily) --> (TMC310911)
# (Duloxetine 60 mg QD) --> (Duloxetine)
# (Duloxetine 30 mg QD) --> (Duloxetine)
# (Duloxetine 120 mg QD) --> (Duloxetine)
# (Duloxetine 90 mg QD) --> (Duloxetine)
# (SCH 420814 100 mg) --> (SCH)
# (SCH 420814 10 mg) --> (SCH)
# (Tiotropium 18 μg) --> (Tiotropium)
# (Irbesartan 150mg / Hydrochlorothiazide 12.5mg) --> (Irbesartan)
# (Irbesartan 150mg) --> (Irbesartan)
# (Viagra® 25 mg tablet daily at night) --> (Viagra®)
# (eltrombopag 25 mg tablet) --> (eltrombopag)
# (eltrombopag 12.5 milligrams (mg) tablet) --> (eltrombopag)
# (GSK962040 50 mg) --> (GSK962040)
# (GSK962040 25 mg) --> (GSK962040)
# (GSK962040 1250 mg) --> (GSK962040)
# (PR104 770 mg/m^2 + sorafenib) --> (PR104)
# (PR104 550 mg/m^2 + sorafenib) --> (PR104)
# (simvastatin 40 mg or atorvastatin 20 mg) --> (simvastatin)
# (atorvastatin 10 mg or simvastatin 20 mg) --> (atorvastatin)
# (Gabapentin 400 mg capsules, single dose) --> (Gabapentin)
# (Gabapentin 400 mg capsules) --> (Gabapentin)
# (Gabapentin 800 mg tablets, single dose (1 tablet)) --> (Gabapentin)
# (paroxetine IR 10mg tablet) --> (paroxetine IR)
# (Paroxetine CR 12.5mg tablet) --> (Paroxetine CR)
# (paroxetine IR 20mg tablet) --> (paroxetine IR)
# (Paroxetine CR 25mg tablet) --> (Paroxetine CR)
# (Comparator: albuterol) --> (albuterol)
# (Comparator: Lipopolysaccharide (LPS)) --> (Lipopolysaccharide (LPS))
# (Ridaforolimus 40 mg) --> (Ridaforolimus)
# (Ridaforolimus 100 mg) --> (Ridaforolimus)
# (Donepezil 5mg) --> (Donepezil)
# (MK-0249 25 mg) --> (MK-0249)
# (MK-0249 7.5 mg) --> (MK-0249)
# (Comparator: metformin) --> (metformin)
# (Comparator: Antidiabetic Standard of Care) --> (Antidiabetic Standard of Care)
# (Trastuzumab emtansine [Kadcyla] 3.6 mg/kg) --> (Trastuzumab emtansine [Kadcyla])
# (Pertuzumab 420 mg) --> (Pertuzumab)
# (Trastuzumab emtansine [Kadcyla] 3.0 mg/kg) --> (Trastuzumab emtansine [Kadcyla])
# (IPX066 195 mg LD) --> (IPX066)
# (CD-LD ER 195 mg) --> (CD-LD ER)
# (IPX066 245 mg LD) --> (IPX066)
# (CD-LD ER 245 mg) --> (CD-LD ER)
# (IPX066 95 mg LD) --> (IPX066)
# (CD-LD ER 95 mg) --> (CD-LD ER)
# (IPX066 145 mg LD) --> (IPX066)
# (CD-LD ER 145 mg) --> (CD-LD ER)
# (Atazanavir 400 mg) --> (Atazanavir)
# (Topiramate 100, Aripiprazole 15mg) --> (Topiramate)
# (Reboxetine, 8 mg) --> (Reboxetine)
# (Desvenlafaxine succinate sustained release 25 mg) --> (Desvenlafaxine succinate sustained release)
# (Desvenlafaxine succinate sustained release 50 mg) --> (Desvenlafaxine succinate sustained release)
# (Dronabinol 30mg/day) --> (Dronabinol)
# (Dronabinol 120mg/day) --> (Dronabinol)
# (Dronabinol 60mg/day) --> (Dronabinol)
# (Comparator: Pegylated Interferon (peg-IFN) alfa-2a) --> (Pegylated Interferon (peg-IFN) alfa-2a)
# (Comparator: vaniprevir (MK7009)) --> (vaniprevir (MK7009))
# (Etravirine (ETR) 200 mg) --> (Etravirine (ETR))
# (Ritonavir (rtv) 100 mg) --> (Ritonavir (rtv))
# (Atazanavir (ATV) 300 mg) --> (Atazanavir (ATV))
# (Atazanavir (ATV) 400 mg) --> (Atazanavir (ATV))
# (Tenofovir disoproxil fumarate (TDF) 300 mg) --> (Tenofovir disoproxil fumarate (TDF))
# (GSK163090 1 mg) --> (GSK163090)
# (GSK163090 3 mg) --> (GSK163090)
# (Mycophenolate Mofetil 250mg) --> (Mycophenolate Mofetil)
# (Gabapentin 1800 mg/day + Lidoderm patch) --> (Gabapentin)
# (BIBW 2992 low (20mg) dosage) --> (BIBW)
# (Vinorelbine i.v. 25 mg/m²) --> (Vinorelbine i.v.)
# (BIBW 2992 high (50mg) dosage) --> (BIBW)
# (Vinorelbine per os 60 mg/m²) --> (Vinorelbine per os)
# (Vinorelbine per os 80 mg/m²) --> (Vinorelbine per os)
# (BIBW 2992 medium (40mg) dosage) --> (BIBW)
# (TMC589337 100 mg) --> (TMC589337)
# (TMC589354 400 mg) --> (TMC589354)
# (TMC589354 100 mg) --> (TMC589354)
# (TMC589354 200 mg) --> (TMC589354)
# (TMC589354 40 mg) --> (TMC589354)
# (TMC310911 300 mg) --> (TMC310911)
# (TMC589337 400 mg) --> (TMC589337)
# (TMC589337 40 mg) --> (TMC589337)
# (TMC310911 600 mg) --> (TMC310911)
# (TMC589337 200 mg) --> (TMC589337)
# (AZD9056 formulation Phase III 50 mg (T)) --> (AZD9056 formulation Phase III)
# (AZD9056 formulation Phase IIb 50 mg (R)) --> (AZD9056 formulation Phase IIb)
# (AZD9056 formulation Phase IIb 200mg (R)) --> (AZD9056 formulation Phase IIb)
# (AZD9056 formulation Phase III 200 mg (T)) --> (AZD9056 formulation Phase III)
# (Siltuximab 8.3 mg/kg or 11 mg/kg) --> (Siltuximab)
# (Methadone 0.2mg/kg) --> (Methadone)
# (Indacaterol xinafoate 400 μg) --> (Indacaterol xinafoate)
# (Indacaterol maleate 400 μg) --> (Indacaterol maleate)
# (Indacaterol acetate 400 μg) --> (Indacaterol acetate)
# (Omeprazole Tablet, 20 mg) --> (Omeprazole Tablet)
# (Midazolam Tablet, 7.5 mg) --> (Midazolam Tablet)
# (Amaryl M SR 1/500 mg) --> (Amaryl M SR)
# (Amaryl Mex 1/500mg, glimepiride 1mg & metformin HCl 500mg) --> (Amaryl Mex)
# (Amaryl M SR 2/500 mg) --> (Amaryl M SR)
# (Amaryl Mex 2/500mg, glimepiride 2mg & metformin HCl 500mg) --> (Amaryl Mex)
# (Amaryl-M 1/500 mg) --> (Amaryl-M)
# (glimepiride 1 mg & metformin HCl 500 mg) --> (glimepiride)
# (Amaryl-M 2/500 mg) --> (Amaryl-M)
# (glimepiride 2 mg & metformin HCl 500 mg) --> (glimepiride)
# (Tolterodine ER 4mg) --> (Tolterodine ER)
# (Vaniprevir 300 mg b.i.d.) --> (Vaniprevir)
# (Vaniprevir 600 mg b.i.d.) --> (Vaniprevir)
# (Rivastigmine 4.6 mg/24 h (5 cm^2)) --> (Rivastigmine)
# (Rivastigmine 13.3 mg/24 h (15 cm^2)) --> (Rivastigmine)
# (Rivastigmine 9.5 mg/24 h (10 cm^2)) --> (Rivastigmine)
# (omeprazole, 20mg twice daily) --> (omeprazole)
# (famotidine 40mg twice daily) --> (famotidine)
# (pantoprazole 40mg once daily) --> (pantoprazole)
# (AMG 827 210 mg) --> (AMG)
# (AMG 827 70 mg) --> (AMG)
# (AMG 827 140 mg) --> (AMG)
# (Loperamide 2mg) --> (Loperamide)
# (HM30181AK 1mg) --> (HM30181AK)
# (HM30181AK 60mg) --> (HM30181AK)
# (HM30181AK 15mg) --> (HM30181AK)
# (HM30181AK 5mg) --> (HM30181AK)
# (Efavirenz 600 mg) --> (Efavirenz)
# (Comparator: metformin 1000 mg) --> (metformin)
# (Comparator: metformin 850 mg) --> (metformin)
# (Comparator: sitagliptin) --> (sitagliptin)
# (Comparator: metformin 500mg) --> (metformin)
# (Comparator: metformin 500 mg) --> (metformin)
# (GI198745 0.5mg) --> (GI198745)
# (GI198745 0.05mg) --> (GI198745)
# (GI198745 2.5mg) --> (GI198745)
# (Rocuronium 0.1 mg/kg maintenance dose) --> (Rocuronium)
# (Rocuronium 0.9 mg/kg intubating dose) --> (Rocuronium)
# (Rocuronium 0.2 mg/kg maintenance) --> (Rocuronium)
# (Rocuronium 0.6 mg/kg intubating dose) --> (Rocuronium)
# (Vecuronium 0.1 mg/kg intubating dose) --> (Vecuronium)
# (Rocuronium 0.15 mg/kg maintenance dose) --> (Rocuronium)
# (Vecuronium 0.025 mg/kg maintenance dose) --> (Vecuronium)
# (Comparator: Treatment B (Zofran, ondansetron)) --> (Treatment B (Zofran, ondansetron))
# (Comparator: Treatment C (Zofran, ondansetron)) --> (Treatment C (Zofran, ondansetron))
# (Comparator: Treatment A (Zofran, ondansetron)) --> (Treatment A (Zofran, ondansetron))
# (Comparator: atorvastatin) --> (atorvastatin)
# (TR-701 FA for injection, 200 mg/vial) --> (TR-701 FA for injection)
# (JNJ-26866138 0.7 mg/m2) --> (JNJ-26866138)
# (JNJ-26866138 1.0 mg/m2) --> (JNJ-26866138)
# (JNJ-26866138 1.3 mg/m2) --> (JNJ-26866138)
# (Midazolam 2 mg) --> (Midazolam)
# (PF-04171327 25 mg) --> (PF-04171327)
# (Moexipril HCl/ Hydrochlorothiazide 15mg/ 25mg Tablet, Paddock Laboratories, Inc.) --> (Moexipril HCl/ Hydrochlorothiazide)
# (Uniretic® 15mg/25mg Tablets) --> (Uniretic®)
# (100 MK-0517 (PS80) + 2 mg midazolam) --> (100 MK-0517 (PS80) +)
# (CDP870 200mg) --> (CDP870)
# (GSK1349572 250 mg) --> (GSK1349572)
# (Moxifloxacin 400 mg) --> (Moxifloxacin)
# (Oxycodone 0mg, IN) --> (Oxycodone)
# (Oxycodone 0mg, p.o.) --> (Oxycodone)
# (Oxycodone 40mg, p.o.) --> (Oxycodone)
# (Oxycodone 20mg, p.o.) --> (Oxycodone)
# (Oxycodone 15mg, IN) --> (Oxycodone)
# (Aprepitant 0mg) --> (Aprepitant)
# (Aprepitant 40mg) --> (Aprepitant)
# (Aprepitant 200mg) --> (Aprepitant)
# (Oxycodone 30mg, IN) --> (Oxycodone)
# (MCS-2 30 mg/day) --> (MCS-2)
# (MCS-2 15 mg/day) --> (MCS-2)
# (Golimumab 2 mg/kg IV) --> (Golimumab)
# (Golimumab 50 mg SC) --> (Golimumab)
# (EMD 525797 500 mg) --> (EMD)
# (EMD 525797 1000 mg) --> (EMD)
# (EMD 525797 750 mg) --> (EMD)
# (EMD 525797 250 mg) --> (EMD)
# (Ustekinumab 90 mg) --> (Ustekinumab)
# (Ustekinumab 45 mg) --> (Ustekinumab)
# (Androcur® 50 mg) --> (Androcur®)
# (Comparator: aspirin) --> (aspirin)
# (Comparator: laropiprant) --> (laropiprant)
# (Comparator: clopidogrel) --> (clopidogrel)
# (Indacaterol 150 μg via the Concept1 dry-powder inhaler) --> (Indacaterol)
# (Indacaterol 60 μg via the Simoon dry-powder inhaler) --> (Indacaterol)
# (Indacaterol 120 μg via the Simoon dry-powder inhaler) --> (Indacaterol)
# (tamsulosin hydrochloride/solifenacin succinate fixed dose combination (0.4 mg/6 mg)) --> (tamsulosin hydrochloride/solifenacin succinate fixed dose combination (0.4 mg)
# (tamsulosin hydrochloride/solifenacin succinate fixed dose combination (0.4 mg/9 mg)) --> (tamsulosin hydrochloride/solifenacin succinate fixed dose combination (0.4 mg)
# (Comparator: Treatment C) --> (Treatment C)
# (Comparator: Treatment B) --> (Treatment B)
# (Dose = 0.1 mg/kg) --> (Dose =)
# (Dose = 0.2 mg/kg) --> (Dose =)
# (MK-8266 1.0 mg) --> (MK-8266)
# (MK-8266 0.1 mg) --> (MK-8266)
# (Comparator: Candesartan cilexetil) --> (Candesartan cilexetil)
# (Comparator: Pbo) --> (Pbo)
# (temozolomide 75 mg x 21 days) --> (temozolomide)
# (ABT-888 40 mg x 5 days) --> (ABT-888)
# (ABT-888 40 mg x 21 days) --> (ABT-888)
# (Temozolomide 150 mg x 5 days) --> (Temozolomide)
# (temozolomide 60 mg x 21 days) --> (temozolomide)
# (ABT-888 20 mg x 21 days) --> (ABT-888)
# (Sitagliptin 100 mg q.d.+ Pioglitazone 45 mg q.d.) --> (Sitagliptin)
# (Ibuprofen 400 mg (if necessary)) --> (Ibuprofen)
# (Comparator: Losartan) --> (Losartan)
# (BIIB014 100mg) --> (BIIB014)
# (BIIB014 50mg) --> (BIIB014)
# (MK-1775 20 mg) --> (MK-1775)
# (5-FU 1000 mg/m^2/day) --> (5-FU)
# (MK-1775 65 mg) --> (MK-1775)
# (acetaminophen 650mg) --> (acetaminophen)
# (Hydrochlorothiazide 12.5mg) --> (Hydrochlorothiazide)
# (Telmisartan 40mg) --> (Telmisartan)
# (Telmisartan 80mg) --> (Telmisartan)
# (Tredaptive (1 g extended release niacin+ 20 mg laropiprant)) --> (Tredaptive (1 g extended release niacin+)
# (Ertugliflozin 2 mg split into twice daily) --> (Ertugliflozin)
# (Ertugliflozin 2 mg single dose) --> (Ertugliflozin)
# (Ertugliflozin 4 mg split into twice daily) --> (Ertugliflozin)
# (Ertugliflozin 4 mg single dose) --> (Ertugliflozin)
# (Comparator: Oxyntomodulin (OXM)) --> (Oxyntomodulin (OXM))
# (Ertugliflozin 5 mg) --> (Ertugliflozin)
# (Ertugliflozin 25 mg) --> (Ertugliflozin)
# (Ertugliflozin 1 mg) --> (Ertugliflozin)
# (concurrent RAD001 5 mg/day) --> (concurrent RAD001)
# (post-radiation RAD001 10 mg/day) --> (post-radiation RAD001)
# (concurrent RAD001 10 mg/day) --> (concurrent RAD001)
# (concurrent RAD001 2.5 mg/day) --> (concurrent RAD001)
# (Bevacizumab 15 mg/kg) --> (Bevacizumab)
# (Endometrin (progesterone 100mg vaginal inserts)) --> (Endometrin (progesterone)
# (Metformin 850 mg) --> (Metformin)
# (Sitagliptin 50 mg) --> (Sitagliptin)
# (Metformin 500 mg) --> (Metformin)
# (ustekinumab 90 mg) --> (ustekinumab)
# (ustekinumab 45 mg) --> (ustekinumab)
# (Chloral Hydrate 10% solution (100 mg/ml)) --> (Chloral Hydrate)
# (Femara Tab.[Letrozole 2.5mg]) --> (Femara Tab.[Letrozole)
# (Peratra Tab.[Letrozole 2.5mg]) --> (Peratra Tab.[Letrozole)
# (PF-03382792 15 mg) --> (PF-03382792)
# (PF-03382792 1.5 mg) --> (PF-03382792)
# (PF-03382792 0.5mg) --> (PF-03382792)
# (PF-03382792 5 mg) --> (PF-03382792)
# (Co-administration of 50 mg sitagliptin and 850 mg metformin) --> (Co-administration of)
# (Co-administration of 50 mg sitagliptin and 500 mg metformin) --> (Co-administration of)
# (sitagliptin/metformin 50 mg/850 mg tablet) --> (sitagliptin/metformin)
# (sitagliptin/metformin 50 mg/500 mg tablet) --> (sitagliptin/metformin)
# (IPX066 195 mg) --> (IPX066)
# (IPX066 245 mg) --> (IPX066)
# (IPX066 95 mg) --> (IPX066)
# (IPX066 145 mg) --> (IPX066)
# (Asenapine 5 mg) --> (Asenapine)
# (Asenapine 10 mg) --> (Asenapine)
# (Aliskiren 150 mg (ALI 150)) --> (Aliskiren)
# (Aliskiren 300 mg (ALI 300)) --> (Aliskiren)
# (Spironolactone 50 mg (SPL 50)) --> (Spironolactone)
# (Telmisartan80mg+Amlodipine 5mg) --> (Telmisartan80mg+Amlodipine)
# (amlodipine 5mg) --> (amlodipine)
# (Canagliflozin 100 mg) --> (Canagliflozin)
# (Canagliflozin 300 mg) --> (Canagliflozin)
# (Comparator: Lorazepam) --> (Lorazepam)
# (Warfarin 25 mg) --> (Warfarin)
# (BI 10773 25 mg) --> (BI)
# (Aprepitant 165 mg) --> (Aprepitant)
# (Aprepitant 250 mg) --> (Aprepitant)
# (Fosaprepitant 150 mg) --> (Fosaprepitant)
# (Ertugliflozin 10 mg tablet) --> (Ertugliflozin)
# (Comparator: Hyperinsulinemic Euglycemic Clamp) --> (Hyperinsulinemic Euglycemic Clamp)
# (JNJ-39588146 30 ng/kg/min) --> (JNJ-39588146)
# (JNJ-39588146 5 ng/kg/min) --> (JNJ-39588146)
# (JNJ-39588146 15 ng/kg/min) --> (JNJ-39588146)
# (Furosemide 60 mg) --> (Furosemide)
# (Aliskiren 150 mg) --> (Aliskiren)
# (Aliskiren 300 mg) --> (Aliskiren)
# (Orlistat 120 mg) --> (Orlistat)
# (Velneperit 400 mg) --> (Velneperit)
# (Oxycodone 20mg) --> (Oxycodone)
# (PF-04531083 2000mg) --> (PF-04531083)
# (PF-04531083 100mg) --> (PF-04531083)
# (Comparator: ISMN ER) --> (ISMN ER)
# (Comparator: Amlodipine) --> (Amlodipine)
# (Comparator: Sulfonylurea) --> (Sulfonylurea)
# (Foradil Aerolizer 12 μg) --> (Foradil Aerolizer)
# (80/2.25 μg Symbicort pMDI) --> (80)
# (lanreotide ATG 120mg) --> (lanreotide ATG)
# (octreotide LAR 30mg) --> (octreotide LAR)
# (Comparator: insulin glargine) --> (insulin glargine)
# (ezetimibe 10 mg) --> (ezetimibe)
# (AZD2516, 40 mg) --> (AZD2516)
# (AZD2516, 16 mg) --> (AZD2516)
# (AZD2516, 5 mg) --> (AZD2516)
# (lopinavir 400 mg/ritonavir 100mg) --> (lopinavir)
# (emtricitabine 200mg /tenofovir 300mg) --> (emtricitabine)
# (Clopidogrel 600 mg post cangrelor) --> (Clopidogrel)
# (5-FU 2600 mg/m², 24-hour-Infusion, day 1) --> (5-FU)
# (Folinic acid 200 mg/m², 1-2-hour-Infusion, day 1) --> (Folinic acid)
# (Oxaliplatin 85 mg/m², 2-hour-Infusion, day 1) --> (Oxaliplatin)
# (Docetaxel 50 mg/m2, 1-hour-Infusion, day 1) --> (Docetaxel)
# (Ipilimumab, 10 mg) --> (Ipilimumab)
# (Ipilimumab, 3 mg) --> (Ipilimumab)
# (Naprosyn 250 mg tablets) --> (Naprosyn)
# (levonorgestrel patch with BMI 32 kg/m2 to <40 kg/m2) --> (levonorgestrel patch with BMI)
# (Solifenacin 5mg) --> (Solifenacin)
# (Solifenacin 10mg) --> (Solifenacin)
# (Glatiramer acetate 20 mg/0.5 mL) --> (Glatiramer acetate)
# (Glatiramer Acetate 20 mg/0.5 mL) --> (Glatiramer Acetate)
# (Warfarin 5 mg + Pitavastatin 4mg once daily (QD)) --> (Warfarin)
# (Warfarin 5mg + Rosuvastatin 40 mg once daily (QD)) --> (Warfarin)
# (E: Combo: Donepezil 10 mg + MK-3134 25 mg + Scopolamine 0.5 mg) --> (E: Combo: Donepezil)
# (D: Donepezil 10 mg + Scopolamine 0.5 mg) --> (D: Donepezil)
# (C: MK-3134 25 mg + Scopolamine 0.5 mg) --> (C: MK-3134)
# (Dextromethorphan 30 mg) --> (Dextromethorphan)
# (Dextromethorphan 60 mg per day) --> (Dextromethorphan)
# (asenapine 5.0 mg) --> (asenapine)
# (asenapine 2.5 mg) --> (asenapine)
# (Part II- etoricoxib 60 mg) --> (Part II- etoricoxib)
# (Part II- etoricoxib 90 mg) --> (Part II- etoricoxib)
# (Part I - etoricoxib 60 mg) --> (Part I - etoricoxib)
# (Part II- naproxen 1000 mg) --> (Part II- naproxen)
# (Part I- naproxen 1000 mg) --> (Part I- naproxen)
# (Part I - etoricoxib 90 mg) --> (Part I - etoricoxib)
# (Albendazole 400mg and ivermectin 200mcg/kg) --> (Albendazole)
# (afatinib 20mg) --> (afatinib)
# (vinorelbine IV 25 or 20mg/m2) --> (vinorelbine IV)
# (afatinib 40mg) --> (afatinib)
# (Methylphenidate 40 mg) --> (Methylphenidate)
# (Domperidon 10 mg) --> (Domperidon)
# (Levodopa/carbidopa 125 mg) --> (Levodopa/carbidopa)
# (Medisorb naltrexone 150 mg) --> (Medisorb naltrexone)
# (Medisorb naltrexone 75 mg) --> (Medisorb naltrexone)
# (Medisorb naltrexone 300 mg) --> (Medisorb naltrexone)
# (Betrixaban 30 mg) --> (Betrixaban)
# (Atorvastatin 10mg) --> (Atorvastatin)
# (Atorvastatin 80mg) --> (Atorvastatin)
# (GSK2190915 100mg QD (AM)) --> (GSK2190915)
# (Montelukast 10mg QD (PM)) --> (Montelukast)
# (GSK2190915 200mg QD (AM)) --> (GSK2190915)
# (INCB007839 300mg BID) --> (INCB007839)
# (Ritalin LA 30 mg) --> (Ritalin LA)
# (Ritalin LA 20 mg) --> (Ritalin LA)
# (Pterostilbene 50 mg twice daily) --> (Pterostilbene)
# (Everolimus 0.25 and 0.75 mg tablets) --> (Everolimus)
# (Zolmitriptan 5 mg Nasal Spray) --> (Zolmitriptan)
# (Eletriptan 40 mg tablet) --> (Eletriptan)
# (GSK2336805 30mg) --> (GSK2336805)
# (GSK2236805 200mg) --> (GSK2236805)
# (GSK2336805 10mg) --> (GSK2336805)
# (GSK2236805 100mg) --> (GSK2236805)
# (GSK2236805 10mg) --> (GSK2236805)
# (GSK2236805 5mg) --> (GSK2236805)
# (GSK2236805 30mg) --> (GSK2236805)
# (GSK2236805 dose to be determined up to 100mg) --> (GSK2236805 dose to be determined up to)
# (Tozadenant (SYN115) 60 mg BID) --> (Tozadenant (SYN115))
# (Tozadenant (SYN115) 240 mg BID) --> (Tozadenant (SYN115))
# (Tozadenant (SYN115) 180 mg BID) --> (Tozadenant (SYN115))
# (Tozadenant (SYN115) 120 mg BID) --> (Tozadenant (SYN115))
# (GSK2190915A 10mg) --> (GSK2190915A)
# (GSK2190915A 25mg) --> (GSK2190915A)
# (GSK2190915A 5mg) --> (GSK2190915A)
# (GSK2190915A 100mg) --> (GSK2190915A)
# (GSK2190915A 50mg) --> (GSK2190915A)
# (Nifedipine GITS (Adalat, BAYA1040), 60 mg) --> (Nifedipine GITS (Adalat)
# (Candesartan cilexetil (Atacand), 4 mg) --> (Candesartan cilexetil (Atacand))
# (Candesartan cilexetil (Atacand), 8 mg) --> (Candesartan cilexetil (Atacand))
# (Nifedipine GITS (Adalat, BAYA1040), 30 mg) --> (Nifedipine GITS (Adalat)
# (Candesartan cilexetil (Atacand), 16 mg) --> (Candesartan cilexetil (Atacand))
# (Candesartan cilexetil (Atacand), 32 mg) --> (Candesartan cilexetil (Atacand))
# (Nifedipine GITS (Adalat, BAYA1040), 20 mg) --> (Nifedipine GITS (Adalat)
# (Flufirvitide-3, 0.1 mg single dose) --> (Flufirvitide-3)
# (Flufirvitide-3, 0.2 mg single dose) --> (Flufirvitide-3)
# (Flufirvitide-3, 0.4 mg single dose) --> (Flufirvitide-3)
# (Flufirvitide-3 0.05 mg single dose) --> (Flufirvitide-3)
# (GSK2190915 100mg milled tablet) --> (GSK2190915)
# (GSK2485852 70 mg) --> (GSK2485852)
# (GSK2485852 420 mg) --> (GSK2485852)
# (GSK2485852 70 mg + Ritonavir 100mg) --> (GSK2485852)
# (GSK2485852 210 mg + Ritonavir 100mg) --> (GSK2485852)
# (GSK2485852 630 mg) --> (GSK2485852)
# (metformin up to 2500mg/d) --> (metformin up to)
# (paclitaxel 175mg/m² q21d) --> (paclitaxel)
# (Paxil CR 25 mg manufactured by SmithKline Beecham (Cork) Limited - Cidra - Puerto Rico) --> (Paxil CR)
# (Paxil CR 25 mg manufactured by GlaxoSmithKline Inc. - Mississauga - Canada) --> (Paxil CR)
# (Canagliflozin 50 mg) --> (Canagliflozin)
# (Canagliflozin 150 mg) --> (Canagliflozin)
# (Canagliflozin, 50 mg) --> (Canagliflozin)
# (Canagliflozin, 300 mg) --> (Canagliflozin)
# (Canagliflozin, 100 mg) --> (Canagliflozin)
# (GSK2118436 75mg) --> (GSK2118436)
# (GSK2118436 150mg) --> (GSK2118436)
# (Pregabalin controlled release, 330 mg) --> (Pregabalin controlled release)
# (darunavir/ritonavir 800/100 mg) --> (darunavir/ritonavir)
# (Aprepitant 125 mg) --> (Aprepitant)
# (Aprepitant 80 mg) --> (Aprepitant)
# (abacavir 600 mg/lamivudine 300 mg) --> (abacavir)
# (Dolutegravir 50 mg/abacavir 600 mg/lamivudine 300 mg) --> (Dolutegravir)
# (Dolutegravir 50 mg) --> (Dolutegravir)
# (Ustekinumab 90 mg SC q12w) --> (Ustekinumab)
# (Ustekinumab 130 mg IV) --> (Ustekinumab)
# (Liraglutide 0.6 mg) --> (Liraglutide)
# (Liraglutide 1.2 mg) --> (Liraglutide)
# (SOM230 LAR 30 mg) --> (SOM230 LAR)
# (SOM230 LAR 10 mg) --> (SOM230 LAR)
# (Chloroquine 600mg) --> (Chloroquine)
# (Chloroquine 600mg (Part 2 )) --> (Chloroquine)
# (Tafenoquine 300mg (Part 2)) --> (Tafenoquine)
# (Tafenoquine 100mg) --> (Tafenoquine)
# (Primaquine 15mg (Part2 )) --> (Primaquine)
# (Chloroquine 300mg) --> (Chloroquine)
# (Tafenoquine 50mg) --> (Tafenoquine)
# (Chloroquine 300mg (Part 2 )) --> (Chloroquine)
# (Tafenoquine 600mg) --> (Tafenoquine)
# (Tafenoquine 300mg) --> (Tafenoquine)
# (Primaquine 15mg) --> (Primaquine)
# (Canagliflozin 100mg) --> (Canagliflozin)
# (Canagliflozin 300mg) --> (Canagliflozin)
# (Dolutegravir 50 mg tablet) --> (Dolutegravir)
# (Dolutegravir 50 mg oral granules) --> (Dolutegravir)
# (BMS-663068 400 mg) --> (BMS-663068)
# (BMS-663068 600 mg) --> (BMS-663068)
# (Raltegravir 400 mg) --> (Raltegravir)
# (Tenofovir 300 mg) --> (Tenofovir)
# (BMS-663068 800 mg) --> (BMS-663068)
# (BMS-663068 1200 mg) --> (BMS-663068)
# (Torisel dose 50 mg and R-CHOP) --> (Torisel dose)
# (Torisel dose 50 mg and R-DHA) --> (Torisel dose)
# (Torisel dose 15 mg and R-FC) --> (Torisel dose)
# (Torisel dose 75 mg and R-FC) --> (Torisel dose)
# (Torisel dose 75 mg and R-CHOP) --> (Torisel dose)
# (Torisel dose 15 mg and R-DHA) --> (Torisel dose)
# (Torisel 75 mg and R-DHA) --> (Torisel)
# (Torisel dose 25 mg and R-CHOP) --> (Torisel dose)
# (Torisel dose 50 mg and R-FC) --> (Torisel dose)
# (Torisel dose 25 mg and R-FC) --> (Torisel dose)
# (Torisel dose 15 mg and R-CHOP) --> (Torisel dose)
# (Torisel dose 25 mg and R-DHA) --> (Torisel dose)
# (Ropinirole 2 mg/d) --> (Ropinirole)
# (Ropinirole 4 mg/d) --> (Ropinirole)
# (Dronabinol 240mg/day) --> (Dronabinol)
# (Epoetin alfa 450 IU/kg once a week) --> (Epoetin alfa)
# (Epoetin alfa 150 IU/kg 3 times a week (TIW)) --> (Epoetin alfa)
# (Epoetin alfa 450 IU/kg once a week (QW)) --> (Epoetin alfa)
# (Epoetin alfa 150 IU/kg 3 times a week) --> (Epoetin alfa)
# (abnobaVISCUM Quercus 2 mg) --> (abnobaVISCUM Quercus)
# (abnobaVISCUM Quercus 0.02 mg) --> (abnobaVISCUM Quercus)
# (abnobaVISCUM Quercus 0.2 mg) --> (abnobaVISCUM Quercus)
# (abnobaVISCUM Quercus 20 mg) --> (abnobaVISCUM Quercus)
# (TH-302 (escalating) with bevacizumab 10mg/kg) --> (TH-302 (escalating) with bevacizumab)
# (GSK2190915 30mg) --> (GSK2190915)
# (Rosuvastatin 10 mg) --> (Rosuvastatin)
# (GSK2190915 100mg) --> (GSK2190915)
# (0.5 mg Lucentis or 1.25 mg Avastin or 2 mg Eylea) --> (0.5 mg Lucentis or)
# (Casodex 80 mg tablet) --> (Casodex)
# (Azithromycin - 250 mg) --> (Azithromycin -)
# (Azithromycin - 1000 mg) --> (Azithromycin -)
# (Diltiazem (Cardizem LA) 240 mg QD) --> (Diltiazem (Cardizem LA))
# (Aspara-CA 600 mg) --> (Aspara-CA)
# (5-mg saxagliptin/1000 mg metformin) --> (5-mg saxagliptin)
# (ritonavir 100mg OAD) --> (ritonavir)
# (darunavir 800mg OAD) --> (darunavir)
# (warfarin 3mg) --> (warfarin)
# (warfarin 5mg) --> (warfarin)
# (warfarin 1mg) --> (warfarin)
# (MEDI-551 2 mg/kg) --> (MEDI-551)
# (MEDI-551 4 mg/kg) --> (MEDI-551)
# (Ixazomib 4 mg Capsule B) --> (Ixazomib)
# (Ixazomib 2.5 mg) --> (Ixazomib)
# (Ixazomib 4 mg Capsule A) --> (Ixazomib)
# (OGX-427 600 mg) --> (OGX-427)
# (OGX-427 1000 mg) --> (OGX-427)
# (Ofatumumab 30mg) --> (Ofatumumab)
# (Ofatumumab 3mg) --> (Ofatumumab)
# (Ofatumumab 60mg) --> (Ofatumumab)
# (paroxetine 20mg QD) --> (paroxetine)
# (Acetaminophen 250 mg, isopropylantipyrine 150 mg and anhydrous caffeine 50 mg) --> (Acetaminophen)
# (PF-05297909 250 mg) --> (PF-05297909)
# (PF-05297909 100 mg) --> (PF-05297909)
# (PF-05297909 525 mg) --> (PF-05297909)
# (PF-05297909 25 mg) --> (PF-05297909)
# (Ointment B: LEO 29102 2.5 mg/g ointment) --> (Ointment B: LEO)
# (Ointment D: LEO 29102 2.5 mg/g plus calcipotriol 50 µg/g ointment) --> (Ointment D: LEO)
# (Ointment G: LEO 29102 2.5 mg/g plus calcipotriol 50 µg/g ointment) --> (Ointment G: LEO)
# (Ointment A: LEO 29102 2.5 mg/g plus calcipotriol 50 µg/g ointment) --> (Ointment A: LEO)
# (Harnal D Tablets and Harnal Capsules (both comprising 0.2 mg tamsulosin HCl)) --> (Harnal D Tablets and Harnal Capsules (both comprising)
# (fenofibric acid 105 mg) --> (fenofibric acid)
# (GFT505 120mg - new formulation) --> (GFT505)
# (GFT505 180mg - new formulation) --> (GFT505)
# (GFT505 300mg - new formulation) --> (GFT505)
# (GFT505 240mg - new formulation) --> (GFT505)
# (doxycycline 200mg) --> (doxycycline)
# (GEn 600 mg) --> (GEn)
# (Isentress® (Raltegravir, 400 mg every 12 hours)) --> (Isentress® (Raltegravir)
# (Treatment C: Hydromorphone 32 mg) --> (Treatment C: Hydromorphone)
# (Treatment D: Hydromorphone 64 mg) --> (Treatment D: Hydromorphone)
# (Treatment B: Hydromorphone 16 mg) --> (Treatment B: Hydromorphone)
# (Treatment A: Hydromorphone 8 mg) --> (Treatment A: Hydromorphone)
# (Pioglitazone 15 mg) --> (Pioglitazone)
# (GSK1605786 500 mg) --> (GSK1605786)
# (Midazolam 3 mg) --> (Midazolam)
# (Omeprazole 40 mg) --> (Omeprazole)
# (Color-matched vehicle containing 0 mg of JNJ 10229570-AAA) --> (Color-matched vehicle containing)
# (Color-matched vehicle in a cream formulation containing 0 mg of JNJ 10229570-AAA) --> (Color-matched vehicle in a cream formulation containing)
# (2mg Glimepiride/10mg Atorvastatin FDC) --> (2mg Glimepiride)
# (3mg Glimepiride/20mg Atorvastatin FDC) --> (3mg Glimepiride)
# (1mg Glimepiride/10mg Atorvastatin FDC) --> (1mg Glimepiride)
# (3mg Glimepiride/10mg Atorvastatin FDC) --> (3mg Glimepiride)
# (2mg Glimepiride/20mg Atorvastatin FDC) --> (2mg Glimepiride)
# (4mg Glimepiride/20mg Atorvastatin FDC) --> (4mg Glimepiride)
# (4mg Glimepiride/10mg Atorvastatin FDC) --> (4mg Glimepiride)
# (1mg Glimepiride/20mg Atorvastatin FDC) --> (1mg Glimepiride)
# (Fixed dose combination capsule containing dutasteride 0.5mg and tamsulosin 0.2mg (fasted state)) --> (Fixed dose combination capsule containing dutasteride)
# (Fixed dose combination capsule containing dutasteride 0.5mg and tamsulosin 0.2mg (fed state)) --> (Fixed dose combination capsule containing dutasteride)
# (GSK2251052 3000 mg) --> (GSK2251052)
# (GSK2251052 1500 mg BID) --> (GSK2251052)
# (GSK2251052 2250 mg) --> (GSK2251052)
# (GSK2251052 1500 mg) --> (GSK2251052)
# (GSK2251052 750 mg) --> (GSK2251052)
# (imipenem/cilastatin 500 mg) --> (imipenem/cilastatin)
# (Relebactam 250 mg) --> (Relebactam)
# (Relebactam 125 mg) --> (Relebactam)
# (IV ondansetron 4 mg q 6 hours for a total of 4 doses) --> (IV ondansetron)
# (Elixir promethazine 25 mg q 6 hours prn after discharge) --> (Elixir promethazine)
# (IV promethazine 25 mg q 6 hours prn) --> (IV promethazine)
# (PP3M 175 mg eq.) --> (PP3M)
# (PP1M 50 mg eq.) --> (PP1M)
# (PP3M 263 mg eq.) --> (PP3M)
# (PP1M 150 mg eq.) --> (PP1M)
# (PP3M 525 mg eq.) --> (PP3M)
# (PP1M 100 mg eq.) --> (PP1M)
# (PP3M 350 mg eq.) --> (PP3M)
# (PP1M 75 mg eq.) --> (PP1M)
# (BIA 9-1067 30 mg) --> (BIA)
# (BIA 9-1067 5 mg) --> (BIA)
# (BIA 9-1067 15 mg) --> (BIA)
# (ER tablet 100 mg AZD3241) --> (ER tablet)
# (ER tablet 25 mg AZD3241) --> (ER tablet)
# (Sinemet® 100/25 mg) --> (Sinemet®)
# (levodopa 100 mg /carbidopa 25 mg) --> (levodopa)
# (Naloxone 0.8 mg/70 kg) --> (Naloxone)
# (Naloxone 0.4 mg/70 kg) --> (Naloxone)
# (Vandetanib 800 mg) --> (Vandetanib)
# (Metformin 1000 mg) --> (Metformin)
# (Fesoterodine PR 8 mg) --> (Fesoterodine PR)
# (Baclofen 60mg) --> (Baclofen)
# (Baclofen 10mg) --> (Baclofen)
# (MK-8457 100 mg) --> (MK-8457)
# (Parenteral aminoglycoside; tobramycin for injection USP OR gentamicin sulfate injection solution concentrate 5mg.kg IV q24h; amikacin sulfate injection USP 20 mg/kg IV q24h) --> (Parenteral aminoglycoside; tobramycin for injection USP OR gentamicin sulfate injection solution concentrate)
# (Bupropion SR 150mg bid) --> (Bupropion SR)
# (Vildagliptin 50 mg BID) --> (Vildagliptin)
# (Saxagliptin 5 mg) --> (Saxagliptin)
# (Vildagliptin 50 mg) --> (Vildagliptin)
# (Omeprazole 20 mg) --> (Omeprazole)
# (Omeprazole 20 mg + Sodium Bicarbonate 1100 mg) --> (Omeprazole)
# (MK-8150 400 mg) --> (MK-8150)
# (MK-8150 320 mg) --> (MK-8150)
# (MK-8150 120 mg) --> (MK-8150)
# (MK-8150 2.0 mg) --> (MK-8150)
# (MK-8150 20 mg) --> (MK-8150)
# (MK-8150 1200 mg) --> (MK-8150)
# (MK-8150 10 mg) --> (MK-8150)
# (MK-8150 40 mg) --> (MK-8150)
# (MK-8150 5.0 mg) --> (MK-8150)
# (MK-8150 600 mg) --> (MK-8150)
# (MK-8150 200 mg) --> (MK-8150)
# (MK-8150 900 mg) --> (MK-8150)
# (MK-8150 160 mg) --> (MK-8150)
# (MK-8150 60 mg) --> (MK-8150)
# (MK-8150 90 mg) --> (MK-8150)
# (MK-8150 50 mg) --> (MK-8150)
# (MK-8150 500 mg) --> (MK-8150)
# (MK-8150 100 mg) --> (MK-8150)
# (TMC278 LA 600mg intramuscular injection) --> (TMC278 LA)
# (GSK1265744 LAP 400mg intramuscular injection) --> (GSK1265744 LAP)
# (GSK1265744 LAP 200mg intramuscular injection) --> (GSK1265744 LAP)
# (TMC278 LA 1200mg intramuscular injection) --> (TMC278 LA)
# (GSK1265744 LAP 200mg subcutaneous injection) --> (GSK1265744 LAP)
# (GSK1265744 LAP 800mg intramuscular injection) --> (GSK1265744 LAP)
# (Either switch to oral therapy: 500 mg of Ciprofloxacin (oral)) --> (Either switch to oral therapy:)
# (or switch to oral therapy: 800 mg/160 mg of sulfamethoxazole/trimethoprim (oral)) --> (or switch to oral therapy:)
# (Methylnaltrexone 12 mg sc.) --> (Methylnaltrexone)
# (MNTX 12 mg sc.) --> (MNTX)
# ...
# (Isoniazid 900 mg orally) --> (Isoniazid)
# (Rifapentine 600 mg orally) --> (Rifapentine)
# (LY03005 extended-release tablets 120 mg group) --> (LY03005 extended-release tablets)
# (LY03005 extended-release tablets 160 mg group) --> (LY03005 extended-release tablets)
# (LY03005 extended-release tablets 40 mg) --> (LY03005 extended-release tablets)
# (LY03005 extended-release tablets 80 mg group) --> (LY03005 extended-release tablets)
# (FDC(MP-513 20mg/Metformin XR 1000mg)) --> (FDC(MP-513)
# (Metformin XR 1000mg) --> (Metformin XR)
# (Glucophage XR 1000mg) --> (Glucophage XR)
# (MP-513 20mg) --> (MP-513)
# (Tenelia 20mg) --> (Tenelia)
# (Dose level 3 ONC201 375mg) --> (Dose level)
# (Dose level 2 ONC201 500mg) --> (Dose level)
# (Dose level 1 ONC201 625mg) --> (Dose level)
# (Tofacitinib 5mg Oral Tablet [Xeljanz] 16 week trial) --> (Tofacitinib)
# (Mycophenolate mofetil 1,000 ~ 2,000mg) --> (Mycophenolate mofetil)
# (depo-medrol 40 mg) --> (depo-medrol)
# (D324 (Memantine HCl 10mg)) --> (D324 (Memantine HCl)
# (Intravenous ACT017 125 mg) --> (Intravenous ACT017)
# (Intravenous ACT017 1000 mg) --> (Intravenous ACT017)
# (Intravenous ACT017 500 mg) --> (Intravenous ACT017)
# (Intravenous ACT017 250 mg) --> (Intravenous ACT017)
# (Ondansetron 16mg with Saline & Tariquidar) --> (Ondansetron)
# (Ondansetron 8mg with Saline & Tariquidar) --> (Ondansetron)
# (Diabex Tab., 500 mg) --> (Diabex Tab.)
# (Tegoprazan 50 mg) --> (Tegoprazan)
# (Esomeprazole 20 mg) --> (Esomeprazole)
# (Propofol 1 mg/kg) --> (Propofol)
# (Etomidate 0.15 mg/kg) --> (Etomidate)
# (Itraconazole Solution 200 mg) --> (Itraconazole Solution)
# (PF-06651600 10 mg tablets) --> (PF-06651600)
# (Raloxifene 60mg/Cholecalciferol 800IU) --> (Raloxifene)
# (Mifeprex® (Mifepristone 200 mg)) --> (Mifeprex® (Mifepristone)
# (ella® (ulipristal acetate emergency contraception 30 mg)) --> (ella® (ulipristal acetate emergency contraception)
# (Lamictal 300 mg) --> (Lamictal)
# (Ondansetron 8mg) --> (Ondansetron)
# (GLP-1 7-36 amide (0.6pmol/kg/min)) --> (GLP-1)
# (GLP-1 7-36 amide (1.2pmol/kg/min)) --> (GLP-1)
# (LPV/r Pellets (40/10mgs) plus ABC/3TC (60/30mgs)) --> (LPV/r Pellets (40)
# (ABC/3TC/LPV/r granules (30/15/40/10 mgs)) --> (ABC)
# (DKN-01 150 mg) --> (DKN-01)
# (Macimorelin 0.5mg/kg body weight) --> (Macimorelin)
# (Macimorelin 0.75mg/kg body weight) --> (Macimorelin)
# (5% lidocaine/5 mg/ml 0.02% estradiol compound cream) --> (5% lidocaine)
# (Magnesium sulfate 50mg) --> (Magnesium sulfate)
# (Magnesium sulfate 30 mg) --> (Magnesium sulfate)
# (Post-laser 10mg minoxidil) --> (Post-laser)
# (Post-laser 5mg minoxidil) --> (Post-laser)
# (Post-laser 20mg minoxidil) --> (Post-laser)
# (Glecaprevir/pibrentasvir (300mg/120mg)) --> (Glecaprevir/pibrentasvir (300mg)
# (Sofosbuvir 400mg [Sovaldi]) --> (Sofosbuvir)
# (12,5 mg of 0,5 % of levobupivacaine) --> (12)
# (ethinyl estradiol 30 μg and norethindrone 1500 μg) --> (ethinyl estradiol)
# (CKD-374 5mg Tab.) --> (CKD-374)
# (Ibuprofen 800 mg) --> (Ibuprofen)
# (PMR 200 mg) --> (PMR)
# (Cilostazol 100 mg) --> (Cilostazol)
# (Atorvastatin 80 mg) --> (Atorvastatin)
# (Atorvastatin 40 mg) --> (Atorvastatin)
# (Atorvastatin 20 mg) --> (Atorvastatin)
# (Carfilzomib 70 mg/m^2) --> (Carfilzomib)
# (Carfilzomib 20 mg/m^2) --> (Carfilzomib)
# (Dara-SC 1800 mg) --> (Dara-SC)
# (Seroquel IR 25mg) --> (Seroquel IR)
# (Quetiapine Formulation 25mg) --> (Quetiapine Formulation)
# (Quetiapine Formulation B 300mg) --> (Quetiapine Formulation B)
# (Quetiapine Formulation A 300mg) --> (Quetiapine Formulation A)
# (Seroquel IR 300mg) --> (Seroquel IR)
# (Anastrozole 1mg) --> (Anastrozole)
# (Dexamethasone 24mg Solution for Injection) --> (Dexamethasone)
# (IPX203 350 mg) --> (IPX203)
# (IPX203 87.5-350mg) --> (IPX203)
# (IPX203 280 mg) --> (IPX203)
# (IPX203 70-280mg) --> (IPX203)
# (IPX203 210 mg) --> (IPX203)
# (IPX203 52.5-210 mg) --> (IPX203)
# (IPX203 140 mg) --> (IPX203)
# (IPX203 35-140 mg) --> (IPX203)
# (Melatonin 5 mg) --> (Melatonin)
# (Levoketoconazole 150 - 600 mg (BID)) --> (Levoketoconazole)
# (Metformin 500 mg Oral Tablet) --> (Metformin)
# (Propranolol 80 mg) --> (Propranolol)
# (Ponesimod dose range (2 - 20 mg)) --> (Ponesimod dose range (2 -)
# (Gemcitabine 1000 mg/m²) --> (Gemcitabine)
# (Gemcitabine 1250 mg/m²) --> (Gemcitabine)
# (Ciprofloxacin 500mg PO BID days 1-29) --> (Ciprofloxacin)
# (Metronidazole 500mg PO TID days 1-29) --> (Metronidazole)
# (Rifampicin 600mg QD tablet and DTG 50mg BD) --> (Rifampicin)
# (Darunavir/ritonavir 800/100 mg tablet) --> (Darunavir/ritonavir)
# (A. Ceftriaxone (Roche ®) 500mg (slow intravenous injection)) --> (A. Ceftriaxone (Roche ®))
# (B. Ceftriaxone rectal dosage form test formulation 1 (1 x 500mg)) --> (B. Ceftriaxone rectal dosage form test formulation)
# (C. Ceftriaxone rectal dosage form test formulation 2 (1 x 500mg)) --> (C. Ceftriaxone rectal dosage form test formulation)
# (Treatment A - 400 mg Fasting) --> (Treatment A -)
# (Treatment B - 400 mg Fed) --> (Treatment B -)
# (Treatment C - 200 mg Fed) --> (Treatment C -)
# (Cabazitaxel 60 mg Solution for Injection) --> (Cabazitaxel)
# (Nilotinib 300 mg) --> (Nilotinib)
# (Nilotinib 300 mg BID and asciminib 20 mg BID or 40 mg QD) --> (Nilotinib)
# (Losartan potassium 100mg) --> (Losartan potassium)
# (Group B: Benzonatate 200mg) --> (Group B: Benzonatate)
# (Group C: Benzonatate 400mg) --> (Group C: Benzonatate)
# (Group A: Benzonatate 100mg) --> (Group A: Benzonatate)
# (Amiloride 20 mg) --> (Amiloride)
# (Amiloride 10 mg) --> (Amiloride)
# (Chlorthalidone 25 mg) --> (Chlorthalidone)
# (Hydrochlorothiazide 50 mg) --> (Hydrochlorothiazide)
# (Dinoprostone 10mg insert OR) --> (Dinoprostone)
# (Fluconazole 150 mg capsules (DiflucanTM)) --> (Fluconazole)
# (Fluconazole (BAYT006267) 150 mg capsules) --> (Fluconazole (BAYT006267))
# (Clomiphene Citrate 25mg) --> (Clomiphene Citrate)
# (Tolbutamide 250 mg) --> (Tolbutamide)
# (Olmesartan Medoxomil 40 mg) --> (Olmesartan Medoxomil)
# (Entrectinib 200 mg (R)) --> (Entrectinib)
# (Entrectinib 600 mg (T1)) --> (Entrectinib)
# (Entrectinib 200 mg (T)) --> (Entrectinib)
# (Entrectinib 600 mg (T2)) --> (Entrectinib)
# (M207 3.8 mg (two 1.9 mg Patches in foil pouches)) --> (M207)
# (M207 3.8 mg (two 1.9 mg Patches in cups)) --> (M207)
# (M207 3.8 mg (two 1.9 mg Patches packaged in cups) --> (M207)
# (Zolmitriptan 2.5 mg Nasal Spray [ZOMIG]) --> (Zolmitriptan)
# (Tofacitinib 5 mg) --> (Tofacitinib)
# (AD-206 40mg) --> (AD-206)
# (AD-206 20mg) --> (AD-206)
# (Esomeprazole 20mg) --> (Esomeprazole)
# (Ustekinumab 6 mg/kg) --> (Ustekinumab)
# (TQ-F3083 capsule 20 mg) --> (TQ-F3083 capsule)
# (TQ-F3083 capsule 10 mg) --> (TQ-F3083 capsule)
# (Rotigotine 1 mg/24 h) --> (Rotigotine)
# (Rotigotine 3 mg/24 h) --> (Rotigotine)
# (Rotigotine 2 mg/24 h) --> (Rotigotine)
# (Add-back capsule (E2 1 mg / NETA 0.5 mg)) --> (Add-back capsule (E2)
# (pamiparib 20 mg) --> (pamiparib)
# (pamiparib 60 mg) --> (pamiparib)
# (Dexamethasone Sodium Sulphate 4mg/1mL) --> (Dexamethasone Sodium Sulphate)
# (Lamivudine 300 mg) --> (Lamivudine)
# (Dolutegravir 50mg Tab) --> (Dolutegravir)
# (Nitroglycerin 0.6 mg) --> (Nitroglycerin)
# (Ketamine 0.5 mg/kg) --> (Ketamine)
# (Ketamine 0.2 mg/kg) --> (Ketamine)
# (Candesartan Cilexetil 32mg) --> (Candesartan Cilexetil)
# (Klacid Syrup® Forte 250 mg/5mL) --> (Klacid Syrup® Forte)
# (Methylprednisolone Acetate BP 40mg/mL:) --> (Methylprednisolone Acetate BP)
# (Tribenoside 400 mg + lidocaine 40 mg suppositories) --> (Tribenoside)
# (CKD-330 16/10mg Tab. 1T and D086 Tab. 1T) --> (CKD-330)
# (CKD-333 16/10/40mg formulation 2 Tab. 1T) --> (CKD-333)
# (CKD-333 16/10/40mg formulation 1 Tab. 1T) --> (CKD-333)
# (5-aminolevulinic acid hydrochloride (5-ALA HCl) 300 mg BID) --> (5-aminolevulinic acid hydrochloride (5-ALA HCl))
# (Artemether 20 mg and lumefantrine 120 mg) --> (Artemether)
# (Sodium ferrous citrate (SFC) 236 mg BID) --> (Sodium ferrous citrate (SFC))
# (5-aminolevulinic acid hydrochloride (5-ALA HCl) 600 mg QD) --> (5-aminolevulinic acid hydrochloride (5-ALA HCl))
# (Sodium ferrous citrate (SFC) 472 mg QD) --> (Sodium ferrous citrate (SFC))
# (Nicotine 12 mg/mL) --> (Nicotine)
# (Nicotine 6 mg/mL) --> (Nicotine)
# (Nicotine 24 mg/mL) --> (Nicotine)
# (Nicotine 0 mg/mL) --> (Nicotine)
# (PF-06865571 400 mg MR in Fasted State) --> (PF-06865571)
# (PF-06865571 400 mg Immediate Release (IR) in Fed State) --> (PF-06865571)
# (PF-06865571 400 mg MR in Fed State) --> (PF-06865571)
# (PF-06865571 50 mg Modified Release (MR) in Fed State) --> (PF-06865571)
# (Carvedilol 25mg) --> (Carvedilol)
# (Metoprolol 100 mg) --> (Metoprolol)
# (Nivolumab 240 mg IV every 2 weeks) --> (Nivolumab)
# (Nivolumab 240 mg IV every 2 weeks + Cabiralizumab 4 mg/kg IV every 2 weeks) --> (Nivolumab)
# (Nivolumab 240 mg IV every 2 weeks + BMS-986253 1200 mg IV every 2 weeks) --> (Nivolumab)
# (Voltaren Ophtha 1 mg/ml, GSK) --> (Voltaren Ophtha)
# (Monopex 1 mg/ml, Théa) --> (Monopex)
# (acetylsalicylic acid (ASA) 81mg) --> (acetylsalicylic acid (ASA))
# (Ustekinumab 90 milligram (mg)) --> (Ustekinumab)
# (Alpha lipoic acid 300mg) --> (Alpha lipoic acid)
# (Flunarizine 5mg) --> (Flunarizine)
# (JNJ-53718678 9 mg/kg) --> (JNJ-53718678)
# (JNJ-53718678 5 mg/kg) --> (JNJ-53718678)
# (JNJ-53718678 6 mg/kg) --> (JNJ-53718678)
# (Single oral dose of 800 mg OZ439) --> (Single oral dose of)
# (Single oral dose of 400 mg OZ439) --> (Single oral dose of)
# (Iohexol Inj 300 milligrams/milliliter (mg/ml)) --> (Iohexol Inj)
# (K-877 CR 0.4 mg/day) --> (K-877 CR)
# (K-877 IR 0.2 mg/day) --> (K-877 IR)
# (K-877 CR 0.8 mg/day) --> (K-877 CR)
# (Varlilumab 3 mg/kg) --> (Varlilumab)
# (CKD-385 64 mg formulation II) --> (CKD-385)
# (CKD-385 64 mg formulation I) --> (CKD-385)
# (Busulfan 3.2 mg/kg/day) --> (Busulfan)
# (Busulfan 0.8 mg/kg) --> (Busulfan)
# (Lu AF11167 MR tablet prototype formulation selected from part A or 1 mg modified release tablet (reference formulation)) --> (Lu AF11167 MR tablet prototype formulation selected from part A or)
# (A: Durvalumab 1500 mg IV) --> (A: Durvalumab)
# (B: Durvalumab 1500 mg IV) --> (B: Durvalumab)
# (Oral Micronized Progesterone 200mg) --> (Oral Micronized Progesterone)
# (Temozolomide 120 mg) --> (Temozolomide)
# (Rabeprazole 20mg) --> (Rabeprazole)
# (Tinidazole 500mg) --> (Tinidazole)
# (Focalin XR (dexmethylphenidate) 40 mg capsule) --> (Focalin XR (dexmethylphenidate))
# (Focalin XR (dexmethylphenidate) 5 mg Capsule) --> (Focalin XR (dexmethylphenidate))
# (Dexmethylphenidate 6.25 mg Tablet) --> (Dexmethylphenidate)
# (CTx-1301 (dexmethylphenidate) 6.25 mg Tablet) --> (CTx-1301 (dexmethylphenidate))
# (Dexmethylphenidate 50 mg Tablet) --> (Dexmethylphenidate)
# (CTx-1301 (dexmethylphenidate) 50 mg tablet) --> (CTx-1301 (dexmethylphenidate))
# (Acetylsalicyclic acid 81 mg tablet qd) --> (Acetylsalicyclic acid)
# (Acetaminophen/Hydrocodone 325 mg/7.5 mg oral tablet) --> (Acetaminophen/Hydrocodone)
# (OxyCODONE 5 mg Oral Tablet) --> (OxyCODONE)
# (Acetaminophen 650 mg Oral Tablet) --> (Acetaminophen)
# (Acetaminophen 325 mg Oral Tablet) --> (Acetaminophen)
# (Rebamipide SR 150mg under fasting condition) --> (Rebamipide SR)
# (Rebamipide SR 150mg after high-fat meal) --> (Rebamipide SR)
# (Rebamipide IR 100mg) --> (Rebamipide IR)
# (Rebamipide SR 150mg) --> (Rebamipide SR)
# (APO-Dabigatran 150mg) --> (APO-Dabigatran)
# (Metformin (Glucophage) 1000mg) --> (Metformin (Glucophage))
# (Brand name: Andrographis paniculata (Shine Hempedu Bumi) 2000mg) --> (Brand name: Andrographis paniculata (Shine Hempedu Bumi))
# (Brand name: Andrographis paniculata (Shine Hempedu Bumi) 1000mg capsules) --> (Brand name: Andrographis paniculata (Shine Hempedu Bumi))
# (Cefuroxime 750mg oral) --> (Cefuroxime)
# (Pamiparib 20 or 40 mg PO BID) --> (Pamiparib)
# (Capecitabine 1000 mg/m² PO BID) --> (Capecitabine)
# (Pemetrexed 500 mg/m² IV) --> (Pemetrexed)
# (Tislelizumab 200 mg, IV) --> (Tislelizumab)
# (Bupropion Hydrochloride 150 mg b.i.d) --> (Bupropion Hydrochloride)
# (Varenicline Tartrate 1 mg b.i.d) --> (Varenicline Tartrate)
# (TS-142, 30 mg) --> (TS-142)
# (TS-142, 20 mg) --> (TS-142)
# (TS-142, 10 mg) --> (TS-142)
# (Metformin Hydrochloride 850 mg Tablets) --> (Metformin Hydrochloride)
# (Cidophage 850 mg) --> (Cidophage)
# (Sildenafil 50 mg) --> (Sildenafil)
# (Evogliptin 5mg) --> (Evogliptin)
# (Metformin ≥ 1000mg) --> (Metformin ≥)
# (Methotrexate 10 mg) --> (Methotrexate)
# (Pemetrexed 500 mg/m2) --> (Pemetrexed)
# (Cisplatin 75 mg/m2) --> (Cisplatin)
# (Dexketoprofen/tramadol (27mg/75mg)) --> (Dexketoprofen/tramadol (27mg)
# (olmesartan 10-20 mg orally once a day) --> (olmesartan)
# (canrenone 50-100 mg orally once a day) --> (canrenone)
# (Diphenhydramine 50 mg/mL) --> (Diphenhydramine)
# (Cetirizine HCl 10 mg/mL) --> (Cetirizine HCl)
# (BAM8-22 2mg/ml) --> (BAM8-22)
# (BAM8-22 0.5 mg/ml) --> (BAM8-22)
# (BAM8-22 1mg/ml) --> (BAM8-22)
# (Omnipaque 300mgI/mL Solution for Injection) --> (Omnipaque)
# (Tepotinib 250 mg) --> (Tepotinib)
# (Tepotinib 100 mg) --> (Tepotinib)
# (Avodart Soft Capsule 0.5mg) --> (Avodart Soft Capsule)
# (Pembrolizumab 200 mg IV every 3 weeks) --> (Pembrolizumab)
# (ADAIR 10mg IR capsules) --> (ADAIR)
# (Meropenem 1000 mg) --> (Meropenem)
# (Marevan 5mg) --> (Marevan)
# (Marevan 3mg) --> (Marevan)
# (Carbidopa 200mg oral dose) --> (Carbidopa)
# (Entacapone 400mg oral dose) --> (Entacapone)
# (5FU, 2400 mg/m2) --> (5FU)
# (5FU, 225 mg/m2) --> (5FU)
# (5FU, 250 mg/m2) --> (5FU)
# (Oxaliplatin 100 mg/m2) --> (Oxaliplatin)
# (Cenerimod 0.5 mg) --> (Cenerimod)
# (Cenerimod 4 mg) --> (Cenerimod)
# (APG2575 800 mg) --> (APG2575)
# (APG2575 400 mg) --> (APG2575)
# (APG2575 600 mg) --> (APG2575)
# (CKD-393 0.5/100/1000mg formulation 1 Tab. 1T) --> (CKD-393)
# (CKD-393 0.5/100/1000mg formulation 2 Tab. 1T) --> (CKD-393)
# (CKD-501 0.5mg Tab. 1T, D759 100mg Tab. 1T and D150 1000mg Tab. 1T) --> (CKD-501)
# (Pembrolizumab 25 mg/1 ML Intravenous Solution [KEYTRUDA]) --> (Pembrolizumab)
# (Acetaminophen 1300mg) --> (Acetaminophen)
# (Pregabalin 100mg) --> (Pregabalin)
# (Blinded CDCA 250 mg TID) --> (Blinded CDCA)
# (Open-Label CDCA 250 mg TID) --> (Open-Label CDCA)
# (Rescue Medication CDCA 250 mg TID) --> (Rescue Medication CDCA)
# (Macitentan 75 mg) --> (Macitentan)
# (Macitentan 37.5 mg) --> (Macitentan)
# (Pramipexole hydrochloride sustained-release tablet (Siforl®) Specification: 0.26mg/ tablet (in pramipexole)) --> (Pramipexole hydrochloride sustained-release tablet (Siforl®) Specification:)
# (Praxol hydrochloride sustained release tablet Specification: 0.375mg/ tablet (in pramipexole hydrochloride)) --> (Praxol hydrochloride sustained release tablet Specification:)
# (Spironolactone 100mg) --> (Spironolactone)
# (Estradiol 2mg) --> (Estradiol)
# (Palbociclib (75, 100, 125 milligram [mg])) --> (Palbociclib (75)
# (H3B-6545 (300, 450 mg)) --> (H3B-6545 (300)
# (Simvastatin 20mg) --> (Simvastatin)
# (Folic Acid tablet medication 1mg/day) --> (Folic Acid tablet medication)
# (Hydroxy Urea tablet medication 20mg/kg/day) --> (Hydroxy Urea tablet medication)
# (lamivudine oral tablet 300mg) --> (lamivudine oral tablet)
# (dolutegravir oral tablet 50mg) --> (dolutegravir oral tablet)
# (emtricitabine/tenofovir alafenamide oral tablet 200mg/25mg) --> (emtricitabine/tenofovir alafenamide oral tablet)
# (tenofovir disoproxil fumarate oral tablet 300mg) --> (tenofovir disoproxil fumarate oral tablet)
# (Dextenza (dexamethasone ophthalmic insert) 0.4mg) --> (Dextenza (dexamethasone ophthalmic insert))
# (Griseofulvin 500 mg) --> (Griseofulvin)
# (Griseofulvin 250 mg) --> (Griseofulvin)
# (Reference Griseofulvin 500 mg) --> (Reference Griseofulvin)
# (Foliglurax 30 mg (treatment B)) --> (Foliglurax)
# (Foliglurax 10 mg (treatment A)) --> (Foliglurax)
# (Relacorilant, 100 mg and 25 mg) --> (Relacorilant)
# (Aspirin 75mg) --> (Aspirin)
# (Quetiapine XR 150 mg) --> (Quetiapine XR)
# (Quetiapine XR 100 mg) --> (Quetiapine XR)
# (Quetiapine XR 50 mg) --> (Quetiapine XR)
# (Fludrocortisone 0.1 Milligrams (mg)) --> (Fludrocortisone)
# (Intracanalicular Dexamethasone, (0.4 mg) Insert) --> (Intracanalicular Dexamethasone)
# (CKD-391 10/10mg) --> (CKD-391)
# (INCB053914 50 mg bis in die (BID)) --> (INCB053914)
# (INCB053914 65 mg BID) --> (INCB053914)
# (INCB053914 80 mg BID) --> (INCB053914)
# (Goserelin 10.8 mg) --> (Goserelin)
# (DKN-01 300mg) --> (DKN-01)
# (Oxaliplatin 130mg/m2) --> (Oxaliplatin)
# (Capecitabine 1000mg/ m2 BID) --> (Capecitabine)
# (DKN-01 600mg) --> (DKN-01)
# (Tislelizumab 200mg) --> (Tislelizumab)

# %%
fixed_drugs_df['cleanedDrugName']
for row in fixed_drugs_df[fixed_drugs_df['cleanedDrugName'].str.contains(',')].iterrows():
    row = row[1]
    print(f"({row[0]}) --> ({row[2]})")
# Out:
# (Comparator: Treatment B (Zofran, ondansetron)) --> (Treatment B (Zofran, ondansetron))
# (Comparator: Treatment C (Zofran, ondansetron)) --> (Treatment C (Zofran, ondansetron))
# (Comparator: Treatment A (Zofran, ondansetron)) --> (Treatment A (Zofran, ondansetron))
